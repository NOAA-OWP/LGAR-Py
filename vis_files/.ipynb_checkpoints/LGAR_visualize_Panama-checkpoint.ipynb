# %%
import numpy as np
from matplotlib.animation import FuncAnimation
# %pylab inline
import pandas as pd

import matplotlib.pyplot as plt
import datetime as dt
import matplotlib.dates as mdates
import os
import pickle

import importlib.util
params_file = '/Users/peterlafollette/Desktop/alt-modular/Modules/GAR/LGAR_BMI/parameter_files/params_Panama.py'
params = importlib.util.spec_from_file_location("params", params_file)
foo = importlib.util.module_from_spec(params)
params.loader.exec_module(foo)
params = foo



time_step = 300/3600 #time step expressed in hours. Used for summary calculations, make sure it's the same as the time step that is in the config file for the LGRA run you're analyzing.
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
###load HYDRUS results here

HYDRUS_output = pd.read_fwf('/Users/peterlafollette/Desktop/alt-modular/Modules/GAR/LGAR_BMI/HYDRUS_files/Panama_HYDRUS/T_Level.txt',widths=[13,13,13,13,13,13,13,13,13,13,13,13,13,13,13,13,13,13,13,13,13,13])

# %%
###load LGAR results here

output = pd.read_pickle("/Users/peterlafollette/Desktop/alt-modular/Modules/GAR/LGAR_BMI/outputs/output_Panama.pkl")        


###states_array = np.load('states_array.npy')

# %%
output
# Out:
#                       #YYYY    MM    DD    HH  MM.1  P(mm/h)  PET(mm/h)  \
# Date
# 2009-05-06 17:00:00  2009.0   5.0   6.0  17.0   0.0      0.0   0.420000
# 2009-05-06 17:05:00  2009.0   5.0   6.0  17.0   5.0      0.0   0.560000
# 2009-05-06 17:10:00  2009.0   5.0   6.0  17.0  10.0      0.0   0.700000
# 2009-05-06 17:15:00  2009.0   5.0   6.0  17.0  15.0      0.0   0.840000
# 2009-05-06 17:20:00  2009.0   5.0   6.0  17.0  20.0      0.0   0.979933
# ...                     ...   ...   ...   ...   ...      ...        ...
# 2009-12-31 23:05:00  2009.0  12.0  31.0  23.0   5.0      0.0   0.560000
# 2009-12-31 23:10:00  2009.0  12.0  31.0  23.0  10.0      0.0   0.512800
# 2009-12-31 23:15:00  2009.0  12.0  31.0  23.0  15.0      0.0   0.465600
# 2009-12-31 23:20:00  2009.0  12.0  31.0  23.0  20.0      0.0   0.418467
# 2009-12-31 23:25:00  2009.0  12.0  31.0  23.0  25.0      0.0   0.371333
#
#                      runoff[mm/h]  actual_infil[mm/h]  ponded_head[mm]  \
# Date
# 2009-05-06 17:00:00           0.0                 0.0                0
# 2009-05-06 17:05:00           0.0                 0.0                0
# 2009-05-06 17:10:00           0.0                 0.0                0
# 2009-05-06 17:15:00           0.0                 0.0                0
# 2009-05-06 17:20:00           0.0                 0.0                0
# ...                           ...                 ...              ...
# 2009-12-31 23:05:00           0.0                 0.0                0
# 2009-12-31 23:10:00           0.0                 0.0                0
# 2009-12-31 23:15:00           0.0                 0.0                0
# 2009-12-31 23:20:00           0.0                 0.0                0
# 2009-12-31 23:25:00           0.0                 0.0                0
#
#                      bottom_flux[mm/h]  water_in_soil[mm]  mass_bal_error(mm)  \
# Date
# 2009-05-06 17:00:00                0.0         288.851380        0.000000e+00
# 2009-05-06 17:05:00                0.0         288.825357        3.817457e-09
# 2009-05-06 17:10:00                0.0         288.790674        4.257411e-09
# 2009-05-06 17:15:00                0.0         288.747344        2.823147e-09
# 2009-05-06 17:20:00                0.0         288.695382        4.493407e-09
# ...                                ...                ...                 ...
# 2009-12-31 23:05:00                0.0         232.365263        1.093313e-10
# 2009-12-31 23:10:00                0.0         232.361698        1.086706e-09
# 2009-12-31 23:15:00                0.0         232.358434        9.036293e-10
# 2009-12-31 23:20:00                0.0         232.355471        9.176868e-10
# 2009-12-31 23:25:00                0.0         232.352808        1.303305e-09
#
#                      actual_ET_per_step(mm)
# Date
# 2009-05-06 17:00:00                0.000000
# 2009-05-06 17:05:00                0.034683
# 2009-05-06 17:10:00                0.043330
# 2009-05-06 17:15:00                0.051962
# 2009-05-06 17:20:00                0.060569
# ...                                     ...
# 2009-12-31 23:05:00                0.003565
# 2009-12-31 23:10:00                0.003264
# 2009-12-31 23:15:00                0.002963
# 2009-12-31 23:20:00                0.002663
# 2009-12-31 23:25:00                0.002362
#
# [68910 rows x 14 columns]

# %%
output.head()
# Out:
#                       #YYYY   MM   DD    HH  MM.1  P(mm/h)  PET(mm/h)  \
# Date
# 2009-05-06 17:00:00  2009.0  5.0  6.0  17.0   0.0      0.0   0.420000
# 2009-05-06 17:05:00  2009.0  5.0  6.0  17.0   5.0      0.0   0.560000
# 2009-05-06 17:10:00  2009.0  5.0  6.0  17.0  10.0      0.0   0.700000
# 2009-05-06 17:15:00  2009.0  5.0  6.0  17.0  15.0      0.0   0.840000
# 2009-05-06 17:20:00  2009.0  5.0  6.0  17.0  20.0      0.0   0.979933
#
#                      runoff[mm/h]  actual_infil[mm/h]  ponded_head[mm]  \
# Date
# 2009-05-06 17:00:00           0.0                 0.0                0
# 2009-05-06 17:05:00           0.0                 0.0                0
# 2009-05-06 17:10:00           0.0                 0.0                0
# 2009-05-06 17:15:00           0.0                 0.0                0
# 2009-05-06 17:20:00           0.0                 0.0                0
#
#                      bottom_flux[mm/h]  water_in_soil[mm]  mass_bal_error(mm)  \
# Date
# 2009-05-06 17:00:00                0.0         288.851380        0.000000e+00
# 2009-05-06 17:05:00                0.0         288.825357        3.817457e-09
# 2009-05-06 17:10:00                0.0         288.790674        4.257411e-09
# 2009-05-06 17:15:00                0.0         288.747344        2.823147e-09
# 2009-05-06 17:20:00                0.0         288.695382        4.493407e-09
#
#                      actual_ET_per_step(mm)
# Date
# 2009-05-06 17:00:00                0.000000
# 2009-05-06 17:05:00                0.034683
# 2009-05-06 17:10:00                0.043330
# 2009-05-06 17:15:00                0.051962
# 2009-05-06 17:20:00                0.060569

# %%
output.tail()
# Out:
#                       #YYYY    MM    DD    HH  MM.1  P(mm/h)  PET(mm/h)  \
# Date
# 2009-12-31 23:05:00  2009.0  12.0  31.0  23.0   5.0      0.0   0.560000
# 2009-12-31 23:10:00  2009.0  12.0  31.0  23.0  10.0      0.0   0.512800
# 2009-12-31 23:15:00  2009.0  12.0  31.0  23.0  15.0      0.0   0.465600
# 2009-12-31 23:20:00  2009.0  12.0  31.0  23.0  20.0      0.0   0.418467
# 2009-12-31 23:25:00  2009.0  12.0  31.0  23.0  25.0      0.0   0.371333
#
#                      runoff[mm/h]  actual_infil[mm/h]  ponded_head[mm]  \
# Date
# 2009-12-31 23:05:00           0.0                 0.0                0
# 2009-12-31 23:10:00           0.0                 0.0                0
# 2009-12-31 23:15:00           0.0                 0.0                0
# 2009-12-31 23:20:00           0.0                 0.0                0
# 2009-12-31 23:25:00           0.0                 0.0                0
#
#                      bottom_flux[mm/h]  water_in_soil[mm]  mass_bal_error(mm)  \
# Date
# 2009-12-31 23:05:00                0.0         232.365263        1.093313e-10
# 2009-12-31 23:10:00                0.0         232.361698        1.086706e-09
# 2009-12-31 23:15:00                0.0         232.358434        9.036293e-10
# 2009-12-31 23:20:00                0.0         232.355471        9.176868e-10
# 2009-12-31 23:25:00                0.0         232.352808        1.303305e-09
#
#                      actual_ET_per_step(mm)
# Date
# 2009-12-31 23:05:00                0.003565
# 2009-12-31 23:10:00                0.003264
# 2009-12-31 23:15:00                0.002963
# 2009-12-31 23:20:00                0.002663
# 2009-12-31 23:25:00                0.002362

# %%
###in LGAR python, actual ET is recorded as a mass per time step, so if one wants to view it as a flux, you have to incorporate the time step

actual_ET = []
for i in range(0,len(output)):
    actual_ET.append((1/time_step)*output['actual_ET_per_step(mm)'][i])

output['actual_ET[mm/h]'] = actual_ET

# %%
plt.plot(output['P(mm/h)'])
plt.plot(output['runoff[mm/h]'])
plt.plot(output['actual_infil[mm/h]'])
plt.plot(output['actual_ET[mm/h]'])

plt.legend(labels=['Precip (mm/h)','runoff (mm/h)','actual infiltration (mm/h)','actual ET (mm/h)'])

# %%
plt.plot(output['P(mm/h)'])

# %%
plt.plot(output['runoff[mm/h]'])

# %%
plt.plot(output['actual_infil[mm/h]'])

# %%
plt.plot(output['actual_ET[mm/h]'])

# %%
print('cumulative precip')
print(sum(output['P(mm/h)'])*5/60)
print(' ')
print('cumulative runoff')
print(sum(output['runoff[mm/h]'])*5/60)
print(' ')
#runoff_efficiency
print('runoff efficiency')
print(sum(output['runoff[mm/h]'])/sum(output['P(mm/h)']))
# Out:
# cumulative precip
# 2627.9096999999997
#
# cumulative runoff
# 798.1119656691085
#
# runoff efficiency
# 0.3037060084937882

# %%
plt.plot(output['bottom_flux[mm/h]'])
np.mean(output['bottom_flux[mm/h]'])
np.min(output['bottom_flux[mm/h]'])
# Out:
# -0.28360319224013614

# %%
plt.plot(output['water_in_soil[mm]'])
plt.xlabel('date')
plt.ylabel('storage (mm)')
#plt.savefig('soil_water_storage.pdf')
#soil water storage
# Out:
# Text(0, 0.5, 'storage (mm)')

# %%
plt.plot(output['mass_bal_error(mm)'])

# %%
#cumulative precip (mm)
sum(output['P(mm/h)'])*time_step
# Out:
# 2627.9097

# %%
#checking that cumulative infiltration + cumulative runoff is the same as cumulative precip
sum(output['actual_infil[mm/h]'])*300/3600 + sum(output['runoff[mm/h]'])*time_step
# Out:
# 2627.9097

# %%
sum(output['runoff[mm/h]'])*time_step
# Out:
# 798.1119656691085

# %%
sum(output['actual_infil[mm/h]'])*time_step
# Out:
# 1829.7977343308914

# %%
#computing cumulative fluxes per time step

cumulative_precip = []
cumulative_runoff = []
cumulative_infilt = []
cumulative_botflx = []
cumulative_evptrs = []
cumulative_evptrs_pot = []


accumulated_precip = 0
accumulated_runoff = 0
accumulated_infilt = 0
accumulated_botflx = 0
accumulated_evptrs = 0
accumulated_evptrs_pot = 0

for i in range(0,len(output)):
    accumulated_precip = accumulated_precip + output['P(mm/h)'][i]*time_step
    cumulative_precip = np.append(cumulative_precip,accumulated_precip)
    
    accumulated_runoff = accumulated_runoff + output['runoff[mm/h]'][i]*time_step
    cumulative_runoff = np.append(cumulative_runoff,accumulated_runoff)
    
    accumulated_infilt = accumulated_infilt + output['actual_infil[mm/h]'][i]*time_step
    cumulative_infilt = np.append(cumulative_infilt,accumulated_infilt)
    
    accumulated_botflx = accumulated_botflx + output['bottom_flux[mm/h]'][i]*time_step
    cumulative_botflx = np.append(cumulative_botflx,accumulated_botflx)
    
    accumulated_evptrs = accumulated_evptrs + output['actual_ET_per_step(mm)'][i]
    cumulative_evptrs = np.append(cumulative_evptrs,accumulated_evptrs)
    
    accumulated_evptrs_pot = accumulated_evptrs_pot + output['PET(mm/h)'][i]*time_step
    cumulative_evptrs_pot = np.append(cumulative_evptrs_pot,accumulated_evptrs_pot)
    
output['cumulative_precip'] = cumulative_precip
output['cumulative_runoff'] = cumulative_runoff
output['cumulative_infilt'] = cumulative_infilt
output['cumulative_botflx'] = cumulative_botflx
output['cumulative_evptrs'] = cumulative_evptrs
output['cumulative_evptrs_pot'] = cumulative_evptrs_pot

# %%
###now formatting HYDRUS outputs for plotting

# %%
HYDRUS_datetime_vec = []
for i in range(0,len(HYDRUS_output['Time'])):
    current_dt = output.index[0] + dt.timedelta(minutes=HYDRUS_output['Time'][i])
    HYDRUS_datetime_vec.append(current_dt)

# %%
HYDRUS_output['HYDRUS_datetime_vec'] = HYDRUS_datetime_vec

# %%
HYDRUS_output = HYDRUS_output.set_index('HYDRUS_datetime_vec')

# %%
HYDRUS_output.head()
# Out:
#                      Time      rTop     rRoot      vTop     vRoot  \
# HYDRUS_datetime_vec
# 2009-05-06 17:05:00   5.0  0.003500  0.003500  0.003500  0.002600
# 2009-05-06 17:10:00  10.0  0.004667  0.004667  0.004664  0.003465
# 2009-05-06 17:15:00  15.0  0.005833  0.005833  0.005831  0.004326
# 2009-05-06 17:20:00  20.0  0.007000  0.007000  0.006999  0.005185
# 2009-05-06 17:25:00  25.0  0.008166  0.008166  0.008165  0.006040
#
#                              vBot  sum(rTop  )   sum(rRoot  )    sum(vTop  \
# HYDRUS_datetime_vec
# 2009-05-06 17:05:00 -1.211400e-09  0.017500       0.017500       0.017502
# 2009-05-06 17:10:00 -4.211000e-09  0.040833       0.040833       0.040824
# 2009-05-06 17:15:00 -8.385500e-10  0.070000       0.070000       0.069981
# 2009-05-06 17:20:00 -6.002700e-11  0.105000       0.105000       0.104980
# 2009-05-06 17:25:00 -3.249600e-09  0.145830       0.145830       0.145800
#
#                      )   sum(vRoot  ...   hRoot    hBot  RunOff  sum(RunOff  \
# HYDRUS_datetime_vec                 ...
# 2009-05-06 17:05:00       0.013002  ... -1000.5 -995.01     0.0         0.0
# 2009-05-06 17:10:00       0.030325  ... -1001.1 -992.85     0.0         0.0
# 2009-05-06 17:15:00       0.051957  ... -1001.8 -990.78     0.0         0.0
# 2009-05-06 17:20:00       0.077882  ... -1002.8 -989.26     0.0         0.0
# 2009-05-06 17:25:00       0.108080  ... -1003.9 -987.89     0.0         0.0
#
#                      )     Volume  sum(Infil  )    sum(Evap  ) TLevel Cum(  \
# HYDRUS_datetime_vec
# 2009-05-06 17:05:00        289.32        0.0       0.017502        1  0.00
# 2009-05-06 17:10:00        289.28        0.0       0.040824        2  0.00
# 2009-05-06 17:15:00        289.24        0.0       0.069981        3  0.00
# 2009-05-06 17:20:00        289.18        0.0       0.104980        4  0.00
# 2009-05-06 17:25:00        289.11        0.0       0.145800        5  0.00
#
#                      WTrans)  Snow Layer
# HYDRUS_datetime_vec
# 2009-05-06 17:05:00            0.0   0.0
# 2009-05-06 17:10:00            0.0   0.0
# 2009-05-06 17:15:00            0.0   0.0
# 2009-05-06 17:20:00            0.0   0.0
# 2009-05-06 17:25:00            0.0   0.0
#
# [5 rows x 22 columns]

# %%
HYDRUS_output.tail()
# Out:
#                          Time      rTop     rRoot      vTop     vRoot  \
# HYDRUS_datetime_vec
# 2009-12-31 23:10:00  344530.0  0.004667  0.004667  0.000342  0.000745
# 2009-12-31 23:15:00  344535.0  0.004273  0.004273  0.000341  0.000682
# 2009-12-31 23:20:00  344540.0  0.003880  0.003880  0.000340  0.000619
# 2009-12-31 23:25:00  344545.0  0.003487  0.003487  0.000339  0.000556
# 2009-12-31 23:30:00  344550.0  0.003094  0.003094  0.000338  0.000493
#
#                              vBot  sum(rTop  )   sum(rRoot  )    sum(vTop  \
# HYDRUS_datetime_vec
# 2009-12-31 23:10:00  5.295500e-10   -1276.4         1351.5        -930.39
# 2009-12-31 23:15:00 -3.917900e-09   -1276.4         1351.5        -930.39
# 2009-12-31 23:20:00  3.205500e-09   -1276.4         1351.5        -930.38
# 2009-12-31 23:25:00  1.419800e-09   -1276.4         1351.6        -930.38
# 2009-12-31 23:30:00 -1.680700e-09   -1276.4         1351.6        -930.38
#
#                      )   sum(vRoot  ...   hRoot    hBot  RunOff  sum(RunOff  \
# HYDRUS_datetime_vec                 ...
# 2009-12-31 23:10:00         970.04  ... -4103.4 -1372.5     0.0      888.43
# 2009-12-31 23:15:00         970.05  ... -4103.9 -1372.7     0.0      888.43
# 2009-12-31 23:20:00         970.05  ... -4104.4 -1372.9     0.0      888.43
# 2009-12-31 23:25:00         970.05  ... -4104.8 -1373.1     0.0      888.43
# 2009-12-31 23:30:00         970.06  ... -4105.3 -1373.3     0.0      888.43
#
#                      )     Volume  sum(Infil  )    sum(Evap  ) TLevel Cum(  \
# HYDRUS_datetime_vec
# 2009-12-31 23:10:00        248.76     1781.9         813.08    73672  0.00
# 2009-12-31 23:15:00        248.75     1781.9         813.08    73673  0.00
# 2009-12-31 23:20:00        248.75     1781.9         813.08    73674  0.00
# 2009-12-31 23:25:00        248.74     1781.9         813.08    73675  0.00
# 2009-12-31 23:30:00        248.74     1781.9         813.09    73676  0.00
#
#                      WTrans)  Snow Layer
# HYDRUS_datetime_vec
# 2009-12-31 23:10:00            0.0   0.0
# 2009-12-31 23:15:00            0.0   0.0
# 2009-12-31 23:20:00            0.0   0.0
# 2009-12-31 23:25:00            0.0   0.0
# 2009-12-31 23:30:00            0.0   0.0
#
# [5 rows x 22 columns]

# %%
HYDRUS_output = HYDRUS_output.resample('300S').interpolate()

# %%
#cumulative forcing data mass curves
plt.plot(output['cumulative_precip'],color='black')
plt.plot(output['cumulative_evptrs_pot'],color='black',linestyle='dotted')
leg = plt.legend(['precip','PET'])
plt.ylabel('cumulative precipitation \n or PET (mm)')
plt.xlabel('date')
# Out:
# Text(0.5, 0, 'date')

# %%
#more formatting for plotting of LGAR and HYDRUS results
times_to_plot = np.arange(time_step,12,time_step)

# %%
min_plt_len = min( len(output),len(HYDRUS_output) )
# plt.plot(np.array(output['cumulative_infilt'])[0:min_plt_len])
# plt.plot(np.array(HYDRUS_output['sum(Infil'])[0:min_plt_len])

plt.plot(output['cumulative_infilt'])[0:min_plt_len]
plt.plot(HYDRUS_output['sum(Infil'])[0:min_plt_len]

plt.plot(output['cumulative_runoff'],ls='dotted')[0:min_plt_len]
plt.plot(HYDRUS_output['sum(RunOff'],ls='dotted')[0:min_plt_len]

HYDRUS_AET = HYDRUS_output[')    sum(Evap'] + HYDRUS_output[')   sum(vRoot']

plt.plot(output['cumulative_evptrs'],ls='dashed')[0:min_plt_len]
plt.plot(HYDRUS_AET,ls='dashed')[0:min_plt_len]


leg = plt.legend(['LGAR cumulative infiltration','HYDRUS cumulative infiltration','LGAR cumulative runoff','HYDRUS cumulative runoff','LGAR cumulative AET','HYDRUS cumulative AET'],prop={'size':8.9})
plt.ylabel('cumulative fluxes (mm)')
#plt.xlabel('time (h)')
plt.xlabel('date')
# Out:
# Text(0.5, 0, 'date')

# %%
###creating a vector that shows how closely LGAR cumulative infiltration mimics that of HYDRUS
percent_diff_cumulative_infiltration = []
for i in range(0, min(len(output)-2, len(HYDRUS_output))):
    percent_diff_cumulative_infiltration.append( abs((HYDRUS_output['sum(Infil'][i]- output['cumulative_infilt'][i])/HYDRUS_output['sum(Infil'][i]*100))
# Out:
# <ipython-input-32-a17cdb55cb1c>:4: RuntimeWarning: invalid value encountered in double_scalars
#   percent_diff_cumulative_infiltration.append( abs((HYDRUS_output['sum(Infil'][i]- output['cumulative_infilt'][i])/HYDRUS_output['sum(Infil'][i]*100))

# %%
###only for synthetic tests, will give nan for real tests

plt.plot(percent_diff_cumulative_infiltration)
plt.hlines(np.nanmean(percent_diff_cumulative_infiltration[0:]),xmin=0,xmax=len(output),color='red')
print(np.nanmean(percent_diff_cumulative_infiltration))
plt.ylabel('cumulative infiltration % difference')
plt.xlabel('time (h)')
#plt.savefig('cumulative_infil_percent_diff_Bushland.pdf')
# Out:
# 5.273937921075058
# Text(0.5, 0, 'time (h)')

# %%
#ensuring no off by 1 error between LGAR and HYDRUS; this just counts the index of the first time step for which there is nonzero infiltration. the variable count should be the same for LGAR and HYDRUS.    
count=0
precip_now = 0
while precip_now==0:
    count = count+1
    precip_now = output['actual_infil[mm/h]'][count]

# %%
count
# Out:
# 589

# %%
count=0
precip_now = 0
while precip_now==0:
    count = count+1
    precip_now = HYDRUS_output['sum(Infil'][count]

# %%
count
# Out:
# 589

# %%
output
# Out:
#                       #YYYY    MM    DD    HH  MM.1  P(mm/h)  PET(mm/h)  \
# Date
# 2009-05-06 17:00:00  2009.0   5.0   6.0  17.0   0.0      0.0   0.420000
# 2009-05-06 17:05:00  2009.0   5.0   6.0  17.0   5.0      0.0   0.560000
# 2009-05-06 17:10:00  2009.0   5.0   6.0  17.0  10.0      0.0   0.700000
# 2009-05-06 17:15:00  2009.0   5.0   6.0  17.0  15.0      0.0   0.840000
# 2009-05-06 17:20:00  2009.0   5.0   6.0  17.0  20.0      0.0   0.979933
# ...                     ...   ...   ...   ...   ...      ...        ...
# 2009-12-31 23:05:00  2009.0  12.0  31.0  23.0   5.0      0.0   0.560000
# 2009-12-31 23:10:00  2009.0  12.0  31.0  23.0  10.0      0.0   0.512800
# 2009-12-31 23:15:00  2009.0  12.0  31.0  23.0  15.0      0.0   0.465600
# 2009-12-31 23:20:00  2009.0  12.0  31.0  23.0  20.0      0.0   0.418467
# 2009-12-31 23:25:00  2009.0  12.0  31.0  23.0  25.0      0.0   0.371333
#
#                      runoff[mm/h]  actual_infil[mm/h]  ponded_head[mm]  ...  \
# Date                                                                    ...
# 2009-05-06 17:00:00           0.0                 0.0                0  ...
# 2009-05-06 17:05:00           0.0                 0.0                0  ...
# 2009-05-06 17:10:00           0.0                 0.0                0  ...
# 2009-05-06 17:15:00           0.0                 0.0                0  ...
# 2009-05-06 17:20:00           0.0                 0.0                0  ...
# ...                           ...                 ...              ...  ...
# 2009-12-31 23:05:00           0.0                 0.0                0  ...
# 2009-12-31 23:10:00           0.0                 0.0                0  ...
# 2009-12-31 23:15:00           0.0                 0.0                0  ...
# 2009-12-31 23:20:00           0.0                 0.0                0  ...
# 2009-12-31 23:25:00           0.0                 0.0                0  ...
#
#                      water_in_soil[mm]  mass_bal_error(mm)  \
# Date
# 2009-05-06 17:00:00         288.851380        0.000000e+00
# 2009-05-06 17:05:00         288.825357        3.817457e-09
# 2009-05-06 17:10:00         288.790674        4.257411e-09
# 2009-05-06 17:15:00         288.747344        2.823147e-09
# 2009-05-06 17:20:00         288.695382        4.493407e-09
# ...                                ...                 ...
# 2009-12-31 23:05:00         232.365263        1.093313e-10
# 2009-12-31 23:10:00         232.361698        1.086706e-09
# 2009-12-31 23:15:00         232.358434        9.036293e-10
# 2009-12-31 23:20:00         232.355471        9.176868e-10
# 2009-12-31 23:25:00         232.352808        1.303305e-09
#
#                      actual_ET_per_step(mm)  actual_ET[mm/h]  \
# Date
# 2009-05-06 17:00:00                0.000000         0.000000
# 2009-05-06 17:05:00                0.034683         0.416195
# 2009-05-06 17:10:00                0.043330         0.519966
# 2009-05-06 17:15:00                0.051962         0.623541
# 2009-05-06 17:20:00                0.060569         0.726831
# ...                                     ...              ...
# 2009-12-31 23:05:00                0.003565         0.042784
# 2009-12-31 23:10:00                0.003264         0.039169
# 2009-12-31 23:15:00                0.002963         0.035556
# 2009-12-31 23:20:00                0.002663         0.031951
# 2009-12-31 23:25:00                0.002362         0.028347
#
#                      cumulative_precip  cumulative_runoff  cumulative_infilt  \
# Date
# 2009-05-06 17:00:00             0.0000           0.000000           0.000000
# 2009-05-06 17:05:00             0.0000           0.000000           0.000000
# 2009-05-06 17:10:00             0.0000           0.000000           0.000000
# 2009-05-06 17:15:00             0.0000           0.000000           0.000000
# 2009-05-06 17:20:00             0.0000           0.000000           0.000000
# ...                                ...                ...                ...
# 2009-12-31 23:05:00          2627.9097         798.111966        1829.797734
# 2009-12-31 23:10:00          2627.9097         798.111966        1829.797734
# 2009-12-31 23:15:00          2627.9097         798.111966        1829.797734
# 2009-12-31 23:20:00          2627.9097         798.111966        1829.797734
# 2009-12-31 23:25:00          2627.9097         798.111966        1829.797734
#
#                      cumulative_botflx  cumulative_evptrs  \
# Date
# 2009-05-06 17:00:00           0.000000           0.000000
# 2009-05-06 17:05:00           0.000000           0.034683
# 2009-05-06 17:10:00           0.000000           0.078013
# 2009-05-06 17:15:00           0.000000           0.129975
# 2009-05-06 17:20:00           0.000000           0.190544
# ...                                ...                ...
# 2009-12-31 23:05:00           2.422808        1883.838612
# 2009-12-31 23:10:00           2.422808        1883.841877
# 2009-12-31 23:15:00           2.422808        1883.844840
# 2009-12-31 23:20:00           2.422808        1883.847502
# 2009-12-31 23:25:00           2.422808        1883.849864
#
#                      cumulative_evptrs_pot
# Date
# 2009-05-06 17:00:00               0.035000
# 2009-05-06 17:05:00               0.081667
# 2009-05-06 17:10:00               0.140000
# 2009-05-06 17:15:00               0.210000
# 2009-05-06 17:20:00               0.291661
# ...                                    ...
# 2009-12-31 23:05:00            2703.014317
# 2009-12-31 23:10:00            2703.057050
# 2009-12-31 23:15:00            2703.095850
# 2009-12-31 23:20:00            2703.130722
# 2009-12-31 23:25:00            2703.161667
#
# [68910 rows x 21 columns]

# %%
HYDRUS_output
# Out:
#                          Time      rTop     rRoot      vTop     vRoot  \
# HYDRUS_datetime_vec
# 2009-05-06 17:05:00       5.0  0.003500  0.003500  0.003500  0.002600
# 2009-05-06 17:10:00      10.0  0.004667  0.004667  0.004664  0.003465
# 2009-05-06 17:15:00      15.0  0.005833  0.005833  0.005831  0.004326
# 2009-05-06 17:20:00      20.0  0.007000  0.007000  0.006999  0.005185
# 2009-05-06 17:25:00      25.0  0.008166  0.008166  0.008165  0.006040
# ...                       ...       ...       ...       ...       ...
# 2009-12-31 23:10:00  344530.0  0.004667  0.004667  0.000342  0.000745
# 2009-12-31 23:15:00  344535.0  0.004273  0.004273  0.000341  0.000682
# 2009-12-31 23:20:00  344540.0  0.003880  0.003880  0.000340  0.000619
# 2009-12-31 23:25:00  344545.0  0.003487  0.003487  0.000339  0.000556
# 2009-12-31 23:30:00  344550.0  0.003094  0.003094  0.000338  0.000493
#
#                              vBot     sum(rTop  )   sum(rRoot  )    sum(vTop  \
# HYDRUS_datetime_vec
# 2009-05-06 17:05:00 -1.211400e-09     0.017500       0.017500       0.017502
# 2009-05-06 17:10:00 -4.211000e-09     0.040833       0.040833       0.040824
# 2009-05-06 17:15:00 -8.385500e-10     0.070000       0.070000       0.069981
# 2009-05-06 17:20:00 -6.002700e-11     0.105000       0.105000       0.104980
# 2009-05-06 17:25:00 -3.249600e-09     0.145830       0.145830       0.145800
# ...                           ...          ...            ...            ...
# 2009-12-31 23:10:00  5.295500e-10 -1276.400000    1351.500000    -930.390000
# 2009-12-31 23:15:00 -3.917900e-09 -1276.400000    1351.500000    -930.390000
# 2009-12-31 23:20:00  3.205500e-09 -1276.400000    1351.500000    -930.380000
# 2009-12-31 23:25:00  1.419800e-09 -1276.400000    1351.600000    -930.380000
# 2009-12-31 23:30:00 -1.680700e-09 -1276.400000    1351.600000    -930.380000
#
#                      )   sum(vRoot  ...   hRoot     hBot  RunOff  sum(RunOff  \
# HYDRUS_datetime_vec                 ...
# 2009-05-06 17:05:00       0.013002  ... -1000.5  -995.01     0.0        0.00
# 2009-05-06 17:10:00       0.030325  ... -1001.1  -992.85     0.0        0.00
# 2009-05-06 17:15:00       0.051957  ... -1001.8  -990.78     0.0        0.00
# 2009-05-06 17:20:00       0.077882  ... -1002.8  -989.26     0.0        0.00
# 2009-05-06 17:25:00       0.108080  ... -1003.9  -987.89     0.0        0.00
# ...                            ...  ...     ...      ...     ...         ...
# 2009-12-31 23:10:00     970.040000  ... -4103.4 -1372.50     0.0      888.43
# 2009-12-31 23:15:00     970.050000  ... -4103.9 -1372.70     0.0      888.43
# 2009-12-31 23:20:00     970.050000  ... -4104.4 -1372.90     0.0      888.43
# 2009-12-31 23:25:00     970.050000  ... -4104.8 -1373.10     0.0      888.43
# 2009-12-31 23:30:00     970.060000  ... -4105.3 -1373.30     0.0      888.43
#
#                      )     Volume  sum(Infil  )    sum(Evap  ) TLevel Cum(  \
# HYDRUS_datetime_vec
# 2009-05-06 17:05:00        289.32        0.0       0.017502        1  0.00
# 2009-05-06 17:10:00        289.28        0.0       0.040824        2  0.00
# 2009-05-06 17:15:00        289.24        0.0       0.069981        3  0.00
# 2009-05-06 17:20:00        289.18        0.0       0.104980        4  0.00
# 2009-05-06 17:25:00        289.11        0.0       0.145800        5  0.00
# ...                           ...        ...            ...            ...
# 2009-12-31 23:10:00        248.76     1781.9     813.080000    73672  0.00
# 2009-12-31 23:15:00        248.75     1781.9     813.080000    73673  0.00
# 2009-12-31 23:20:00        248.75     1781.9     813.080000    73674  0.00
# 2009-12-31 23:25:00        248.74     1781.9     813.080000    73675  0.00
# 2009-12-31 23:30:00        248.74     1781.9     813.090000    73676  0.00
#
#                      WTrans)  Snow Layer
# HYDRUS_datetime_vec
# 2009-05-06 17:05:00            0.0   0.0
# 2009-05-06 17:10:00            0.0   0.0
# 2009-05-06 17:15:00            0.0   0.0
# 2009-05-06 17:20:00            0.0   0.0
# 2009-05-06 17:25:00            0.0   0.0
# ...                            ...   ...
# 2009-12-31 23:10:00            0.0   0.0
# 2009-12-31 23:15:00            0.0   0.0
# 2009-12-31 23:20:00            0.0   0.0
# 2009-12-31 23:25:00            0.0   0.0
# 2009-12-31 23:30:00            0.0   0.0
#
# [68910 rows x 22 columns]
